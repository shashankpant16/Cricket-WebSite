# %% [markdown]
# # CRICKET PYTHON
# ### This program will fetch all live and recently finished cricket matches and will display the scorecard with scoreboard .
# ### Here i have used cricbuzz api, which is easy way to pull out the scores of live matches.
# ### If you want to do the same thing with web scrapping see my "Getting-live-cricket-score-using-python" repository.

# %%
#Importing the necessary libraries.
from pycricbuzz import Cricbuzz
import pandas as pd

#creating object of Cricbuzz
cb = Cricbuzz()

# %%
#This method will print the basic match information.

def matchInfo(match):
    print(match['srs'],"\n"+match['team1']['name'],' vs ',match['team2']['name'])
    print("**************************************************************")
    print(match['mnum'],"\tToss-> ",match['toss'])
    print("Status: ",match['status'],"\n")
    #print(match['team1']['name']," -> ",match['team1']['squad'])
    #print(match['team2']['name']," -> ",match['team2']['squad'])
    #print("\n\n")

# %%
#This method will display the scorecards of both the teams.

def scorecard(ref):
    for i in ref.values():
        team1_bat = []
        team2_bowl = []
        print(i[0]['batteam'],":",i[0]['runs']," for ",i[0]['wickets'])
        print("Overs : ",i[0]['overs'])
        print("\n\n")
        for j in i[0]['batcard']:
            team1_bat.append(j)
        for k in i[0]['bowlcard']:
            team2_bowl.append(k)
        df_bat = pd.DataFrame(team1_bat,index=range(len(team1_bat)))
        df_bowl = pd.DataFrame(team2_bowl,index=range(len(team2_bowl)))
        df_bat = df_bat[['name','runs','balls','fours','six','dismissal']]
        df_bowl = df_bowl[["name","overs","wickets","runs","maidens","wides","nballs"]]
        print("BATTING\n")
        print(df_bat)
        print("\n\nBOWLING\n")
        print(df_bowl)

# %%
#Here is the main calling of the program and both the functions are called in appropriate order

k=1
for i in cb.matches():
    print("\n\n")
    print("############################################## MATCH ",k," ###################################################")
    print("\n\n")
    matchInfo(i)
    try:
        scorecard(cb.scorecard(i['id']))
    #cb.livescore(i['id'])
    except:
        pass
    k+=1
# Out:
# ############################################## MATCH  1  ###################################################
#
#
#
# ICC Cricket World Cup 2019
# India  vs  Australia
# **************************************************************
# Match 14 	Toss->
# Status:  Starts in 4 hrs 19 mins
#
#
#
#
# ############################################## MATCH  2  ###################################################
#
#
#
# ICC Cricket World Cup 2019
# England  vs  Bangladesh
# **************************************************************
# Match 12 	Toss->  Bangladesh elect to bowl
# Status:  ENG won by 106 runs
#
# Bangladesh : 280  for  10
# Overs :  48.5
#
#
#
# BATTING
#
#                 name runs balls fours six                  dismissal
# 0              Tamim   19    29     1   0       c Morgan b Mark Wood
# 1      Soumya Sarkar    2     8     0   0             b Jofra Archer
# 2             Shakib  121   119    12   1                   b Stokes
# 3              Rahim   44    50     2   0           c Roy b Plunkett
# 4             Mithun    0     2     0   0   c Bairstow b Adil Rashid
# 5        Mahmudullah   28    41     1   1     c Bairstow b Mark Wood
# 6   Mosaddek Hossain   26    16     4   0    c Jofra Archer b Stokes
# 7          Saifuddin    5     8     0   0                   b Stokes
# 8       Mehidy Hasan   12     8     2   0  c Bairstow b Jofra Archer
# 9            Mortaza    4     9     0   0                    not out
# 10        Mustafizur    0     3     0   0  c Bairstow b Jofra Archer
#
#
# BOWLING
#
#            name overs wickets runs maidens wides nballs
# 0        Woakes     8       0   67       0     0      0
# 1  Jofra Archer   8.5       3   29       2     5      0
# 2      Plunkett     8       1   36       0     2      0
# 3     Mark Wood     8       2   52       0     0      0
# 4   Adil Rashid    10       1   64       0     2      0
# 5        Stokes     6       3   23       1     1      0
#
#
#
# ############################################## MATCH  3  ###################################################
#
#
#
# ICC Cricket World Cup 2019
# Afghanistan  vs  New Zealand
# **************************************************************
# Match 13 	Toss->  New Zealand elect to bowl
# Status:  NZ won by 7 wkts
#
# New Zealand : 173  for  3
# Overs :  32.1
#
#
#
# BATTING
#
#           name runs balls fours six                  dismissal
# 0      Guptill    0     1     0   0  c Najibullah b Aftab Alam
# 1        Munro   22    24     4   0       c Hamid b Aftab Alam
# 2   Williamson   79    99     9   0                    not out
# 3  Ross Taylor   48    52     6   1               b Aftab Alam
# 4       Latham   13    18     1   0                    not out
#
#
# BOWLING
#
#          name overs wickets runs maidens wides nballs
# 0  Aftab Alam   8.1       3   45       0     1      0
# 1       Hamid     7       0   30       0     3      0
# 2        Naib     9       0   55       1     1      1
# 3        Nabi     3       0   18       0     1      0
# 4      Rahmat     5       0   21       0     0      0
#
#
#
# ############################################## MATCH  4  ###################################################
#
#
#
# West Indies Women tour of England 2019
# England Women  vs  West Indies Women
# **************************************************************
# 2nd ODI (ICC Championship match) 	Toss->
# Status:  Starts in 4 hrs 49 mins
#
#
#
#
# ############################################## MATCH  5  ###################################################
#
#
#
# Sri Lanka A tour of India 2019
# India A  vs  Sri Lanka A
# **************************************************************
# 2nd Unofficial ODI 	Toss->  India A elect to bowl
# Status:  IND A won by 10 wkts
#
# India A : 243  for  0
# Overs :  33.3
#
#
#
# BATTING
#
#               name runs balls fours six  dismissal
# 0  Ruturaj Gaikwad  125    94    14   4    not out
# 1     Shubman Gill  109    96    14   2  retd hurt
# 2           Chopra    1    11     0   0    not out
#
#
# BOWLING
#
#               name overs wickets runs maidens wides nballs
# 0    Lahiru Kumara     5       0   42       0     0      0
# 1  Asitha Fernando     5       0   28       0     0      0
# 2        Dananjaya     9       0   56       0     0      0
# 3   Kamindu Mendis   5.3       0   44       0     0      0
# 4  Ishan Jayaratne     2       0   20       0     0      0
# 5       Jayasuriya     5       0   32       0     0      0
# 6        Priyanjan     2       0   19       0     0      0
#
#
#
# ############################################## MATCH  6  ###################################################
#
#
#
# County Championship Division One 2019
# Nottinghamshire  vs  Hampshire
# **************************************************************
# County Div 1 	Toss->
# Status:  Starts in 4 hrs 49 mins
